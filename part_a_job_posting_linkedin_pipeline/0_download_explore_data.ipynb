# %%
# %pip install opendatasets
# Out:
# Requirement already satisfied: opendatasets in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (0.1.22)
# Requirement already satisfied: tqdm in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from opendatasets) (4.65.0)
# Requirement already satisfied: kaggle in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from opendatasets) (1.6.6)
# Requirement already satisfied: click in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from opendatasets) (8.0.4)
# Requirement already satisfied: six>=1.10 in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from kaggle->opendatasets) (2023.7.22)
# Requirement already satisfied: python-dateutil in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: requests in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from kaggle->opendatasets) (5.0.2)
# Requirement already satisfied: urllib3 in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from kaggle->opendatasets) (1.26.16)
# Requirement already satisfied: bleach in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from kaggle->opendatasets) (4.1.0)
# Requirement already satisfied: packaging in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from bleach->kaggle->opendatasets) (23.1)
# Requirement already satisfied: webencodings in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from requests->kaggle->opendatasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/xiangivyli/anaconda3/lib/python3.11/site-packages (from requests->kaggle->opendatasets) (3.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import opendatasets as od
import pandas as pd
# Out:
# /home/xiangivyli/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
dataset_url = "https://www.kaggle.com/datasets/arshkon/linkedin-job-postings?resource=download"
download_path = "./data"

# %%
#enter username & key downloaded from https://kaggle.com/me/account create new api token
od.download(dataset_url, data_dir=download_path)

# %%
# !tree
# Out:
# .
# ├── README.md
# ├── airflow
# │   ├── Dockerfile
# │   ├── README.md
# │   ├── airflow_settings.yaml
# │   ├── dags
# │   │   ├── raw_to_gcs.py
# │   │   └── spark_repartition.py
# │   ├── include
# │   │   ├── dataset
# │   │   │   └── linkedin-job-postings
# │   │   │       ├── company_details
# │   │   │       │   ├── companies.csv
# │   │   │       │   ├── company_industries.csv
# │   │   │       │   ├── company_specialities.csv
# │   │   │       │   └── employee_counts.csv
# │   │   │       ├── job_details
# │   │   │       │   ├── benefits.csv
# │   │   │       │   ├── job_industries.csv
# │   │   │       │   ├── job_skills.csv
# │   │   │       │   └── salaries.csv
# │   │   │       ├── job_postings.csv
# │   │   │       └── maps
# │   │   │           ├── industries.csv
# │   │   │           └── skills.csv
# │   │   ├── gcp
# │   │   │   └── airflow-gcp-biquery.json
# │   │   ├── lib
# │   │   │   └── gcs-connector-hadoop3-2.2.5.jar
# │   │   └── pyspark_script.py
# │   ├── packages.txt
# │   ├── plugins
# │   ├── requirements.txt
# │   └── tests
# │       └── dags
# │           └── test_dag_example.py
# ├── data
# │   ├── linkedin-job-postings
# │   │   ├── company_details
# │   │   │   ├── companies.csv
# │   │   │   ├── company_industries.csv
# │   │   │   ├── company_specialities.csv
# │   │   │   └── employee_counts.csv
# │   │   ├── job_details
# │   │   │   ├── benefits.csv
# │   │   │   ├── job_industries.csv
# │   │   │   ├── job_skills.csv
# │   │   │   └── salaries.csv
# │   │   ├── job_postings.csv
# │   │   └── maps
# │   │       ├── industries.csv
# │   │       └── skills.csv
# │   └── pq-linkedin-job-postings
# │       ├── pq_benefits
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
# │       │   ├── part-00001-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
# │       │   ├── part-00002-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
# │       │   ├── part-00003-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
# │       │   └── part-00004-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
# │       ├── pq_companies
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
# │       │   ├── part-00001-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
# │       │   ├── part-00002-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
# │       │   ├── part-00003-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
# │       │   └── part-00004-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
# │       ├── pq_company_industries
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-1519a410-b2fb-4ba3-b2c3-a1b3881845ae-c000.snappy.parquet
# │       │   └── part-00001-1519a410-b2fb-4ba3-b2c3-a1b3881845ae-c000.snappy.parquet
# │       ├── pq_company_specialities
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
# │       │   ├── part-00001-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
# │       │   ├── part-00002-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
# │       │   ├── part-00003-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
# │       │   └── part-00004-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
# │       ├── pq_employee
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
# │       │   ├── part-00001-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
# │       │   ├── part-00002-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
# │       │   ├── part-00003-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
# │       │   └── part-00004-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
# │       ├── pq_industries
# │       │   ├── _SUCCESS
# │       │   └── part-00000-e3e6e17b-8763-4c19-9458-883bb696e2ae-c000.snappy.parquet
# │       ├── pq_job_industries
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
# │       │   ├── part-00001-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
# │       │   ├── part-00002-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
# │       │   ├── part-00003-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
# │       │   └── part-00004-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
# │       ├── pq_job_postings
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00001-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00002-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00003-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00004-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00005-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00006-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00007-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   ├── part-00008-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       │   └── part-00009-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
# │       ├── pq_job_skills
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
# │       │   ├── part-00001-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
# │       │   ├── part-00002-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
# │       │   ├── part-00003-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
# │       │   └── part-00004-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
# │       ├── pq_salaries
# │       │   ├── _SUCCESS
# │       │   ├── part-00000-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
# │       │   ├── part-00001-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
# │       │   ├── part-00002-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
# │       │   ├── part-00003-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
# │       │   └── part-00004-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
# │       └── pq_skills
# │           ├── _SUCCESS
# │           └── part-00000-9c445072-e0bc-4cc1-81de-c54d58215ade-c000.snappy.parquet
# ├── dbt_transformation
# │   ├── README.md
# │   ├── analyses
# │   ├── dbt_project.yml
# │   ├── macros
# │   ├── models
# │   │   ├── marts
# │   │   │   ├── agg_job_posting.sql
# │   │   │   ├── company_info.sql
# │   │   │   ├── industry_info.sql
# │   │   │   ├── schema.yml
# │   │   │   └── skills_info.sql
# │   │   └── staging
# │   │       ├── company_info
# │   │       │   ├── stg_company_info__companies.sql
# │   │       │   └── stg_company_info__employee_count.sql
# │   │       ├── fact
# │   │       │   └── stg_fact__job_postings.sql
# │   │       ├── industry
# │   │       │   ├── dim_industry.sql
# │   │       │   └── stg_industry__job_industries.sql
# │   │       ├── schema.yml
# │   │       └── skills
# │   │           ├── dim_skills.sql
# │   │           └── stg_skills__job_skills.sql
# │   ├── seeds
# │   │   ├── industries.csv
# │   │   └── skills.csv
# │   └── snapshots
# ├── download_explore_data.ipynb
# ├── image
# │   ├── 1. overview_of_size.png
# │   └── 2. overview_of_rows.png
# └── kaggle_data_extraction.ipynb
#
# 43 directories, 115 files

# %%
#list files

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print(f"{indent}{os.path.basename(root)}/")
        subindent = ' ' * 4 * (level + 1)
        for f in files:
            print(f"{subindent}{f}")

list_files('.')
# Out:
# ./
#     .gitignore
#     download_explore_data.ipynb
#     kaggle_data_extraction.ipynb
#     README.md
#     dbt_transformation/
#         dbt_project.yml
#         .gitignore
#         README.md
#         .gitkeep
#         macros/
#             .gitkeep
#         seeds/
#             skills.csv
#             industries.csv
#             .gitkeep
#         models/
#             staging/
#                 schema.yml
#                 industry/
#                     dim_industry.sql
#                     stg_industry__job_industries.sql
#                 skills/
#                     dim_skills.sql
#                     stg_skills__job_skills.sql
#                 fact/
#                     stg_fact__job_postings.sql
#                 company_info/
#                     stg_company_info__employee_count.sql
#                     stg_company_info__companies.sql
#             marts/
#                 agg_job_posting.sql
#                 industry_info.sql
#                 company_info.sql
#                 skills_info.sql
#                 schema.yml
#         analyses/
#             .gitkeep
#         snapshots/
#             .gitkeep
#     data/
#         pq-linkedin-job-postings/
#             pq_job_skills/
#                 .part-00002-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet.crc
#                 part-00002-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
#                 .part-00003-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet.crc
#                 _SUCCESS
#                 .part-00004-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet.crc
#                 part-00000-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
#                 part-00003-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
#                 ._SUCCESS.crc
#                 part-00001-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
#                 .part-00000-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet.crc
#                 .part-00001-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet.crc
#                 part-00004-26c41008-786e-470d-920a-1d6e96ac1247-c000.snappy.parquet
#             pq_benefits/
#                 _SUCCESS
#                 .part-00002-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet.crc
#                 .part-00004-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet.crc
#                 part-00000-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
#                 ._SUCCESS.crc
#                 part-00004-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
#                 part-00003-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
#                 .part-00000-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet.crc
#                 .part-00003-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet.crc
#                 .part-00001-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet.crc
#                 part-00002-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
#                 part-00001-9144750d-f166-45a2-8d0b-c7bd53845cf5-c000.snappy.parquet
#             pq_salaries/
#                 _SUCCESS
#                 part-00001-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
#                 part-00002-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
#                 part-00004-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
#                 .part-00003-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet.crc
#                 part-00000-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
#                 ._SUCCESS.crc
#                 .part-00002-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet.crc
#                 .part-00001-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet.crc
#                 part-00003-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet
#                 .part-00000-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet.crc
#                 .part-00004-f4b3cd91-2072-4623-9b91-28ac7a2d2fd7-c000.snappy.parquet.crc
#             pq_skills/
#                 _SUCCESS
#                 .part-00000-9c445072-e0bc-4cc1-81de-c54d58215ade-c000.snappy.parquet.crc
#                 ._SUCCESS.crc
#                 part-00000-9c445072-e0bc-4cc1-81de-c54d58215ade-c000.snappy.parquet
#             pq_company_industries/
#                 _SUCCESS
#                 part-00000-1519a410-b2fb-4ba3-b2c3-a1b3881845ae-c000.snappy.parquet
#                 .part-00001-1519a410-b2fb-4ba3-b2c3-a1b3881845ae-c000.snappy.parquet.crc
#                 part-00001-1519a410-b2fb-4ba3-b2c3-a1b3881845ae-c000.snappy.parquet
#                 ._SUCCESS.crc
#                 .part-00000-1519a410-b2fb-4ba3-b2c3-a1b3881845ae-c000.snappy.parquet.crc
#             pq_industries/
#                 _SUCCESS
#                 .part-00000-e3e6e17b-8763-4c19-9458-883bb696e2ae-c000.snappy.parquet.crc
#                 ._SUCCESS.crc
#                 part-00000-e3e6e17b-8763-4c19-9458-883bb696e2ae-c000.snappy.parquet
#             pq_company_specialities/
#                 .part-00003-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet.crc
#                 _SUCCESS
#                 part-00002-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
#                 .part-00000-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet.crc
#                 .part-00001-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet.crc
#                 part-00004-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
#                 ._SUCCESS.crc
#                 .part-00004-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet.crc
#                 part-00000-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
#                 part-00001-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
#                 .part-00002-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet.crc
#                 part-00003-3761cabf-bd41-4527-8e7f-16d2e58b629e-c000.snappy.parquet
#             pq_companies/
#                 .part-00003-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet.crc
#                 _SUCCESS
#                 part-00001-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
#                 .part-00001-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet.crc
#                 part-00003-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
#                 part-00000-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
#                 part-00002-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
#                 .part-00002-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet.crc
#                 ._SUCCESS.crc
#                 part-00004-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet
#                 .part-00004-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet.crc
#                 .part-00000-bdba4f17-9856-4bfb-99e3-4a3cbf63e889-c000.snappy.parquet.crc
#             pq_job_postings/
#                 .part-00009-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 _SUCCESS
#                 .part-00005-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 part-00005-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 .part-00007-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 part-00002-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 .part-00008-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 part-00009-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 part-00008-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 .part-00000-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 part-00004-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 ._SUCCESS.crc
#                 .part-00003-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 part-00006-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 .part-00001-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 .part-00006-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 .part-00004-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#                 part-00000-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 part-00007-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 part-00001-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 part-00003-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet
#                 .part-00002-1d42a809-5abf-4f6e-b0df-c42610a14b9c-c000.snappy.parquet.crc
#             pq_employee/
#                 part-00004-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
#                 _SUCCESS
#                 .part-00004-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet.crc
#                 .part-00001-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet.crc
#                 part-00002-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
#                 part-00001-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
#                 .part-00000-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet.crc
#                 ._SUCCESS.crc
#                 .part-00002-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet.crc
#                 part-00003-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
#                 .part-00003-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet.crc
#                 part-00000-520f3b70-1bc4-4488-b094-68a916f97e0a-c000.snappy.parquet
#             pq_job_industries/
#                 part-00001-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
#                 _SUCCESS
#                 .part-00001-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet.crc
#                 part-00004-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
#                 .part-00000-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet.crc
#                 part-00000-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
#                 ._SUCCESS.crc
#                 .part-00002-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet.crc
#                 .part-00004-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet.crc
#                 part-00003-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
#                 .part-00003-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet.crc
#                 part-00002-ddf44514-46b1-4fac-9ce8-f7912b69b102-c000.snappy.parquet
#         linkedin-job-postings/
#             job_postings.csv
#             maps/
#                 skills.csv
#                 industries.csv
#             company_details/
#                 employee_counts.csv
#                 companies.csv
#                 company_specialities.csv
#                 company_industries.csv
#             job_details/
#                 job_industries.csv
#                 job_skills.csv
#                 benefits.csv
#                 salaries.csv
#     airflow/
#         Dockerfile
#         packages.txt
#         .gitignore
#         airflow_settings.yaml
#         .env
#         .dockerignore
#         README.md
#         requirements.txt
#         tests/
#             dags/
#                 test_dag_example.py
#         plugins/
#         include/
#             pyspark_script.py
#             lib/
#                 gcs-connector-hadoop3-2.2.5.jar
#             gcp/
#                 airflow-gcp-biquery.json
#             dataset/
#                 linkedin-job-postings/
#                     job_postings.csv
#                     maps/
#                         skills.csv
#                         industries.csv
#                     company_details/
#                         employee_counts.csv
#                         companies.csv
#                         company_specialities.csv
#                         company_industries.csv
#                     job_details/
#                         job_industries.csv
#                         job_skills.csv
#                         benefits.csv
#                         salaries.csv
#         .astro/
#             test_dag_integrity_default.py
#             config.yaml
#         dags/
#             .airflowignore
#             spark_repartition.py
#             raw_to_gcs.py
#     image/
#         2. overview_of_rows.png
#         1. overview_of_size.png
#     .ipynb_checkpoints/
#         kaggle_data_extraction-checkpoint.ipynb

# %%
#get sizes of each file

def get_size(start_path = '.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            if f.endswith('.csv'):
                fp = os.path.join(dirpath, f)
                total_size += os.path.getsize(fp)
    return total_size

def print_file_sizes(start_path = '.'):
    for dirpath, dirnames, filenames in os.walk(start_path):
        print(f"Directory: {dirpath}")
        for f in filenames:
            if f.endswith('.csv'):
                fp = os.path.join(dirpath, f)
                size = os.path.getsize(fp)
                print(f"    {f} - {size} bytes")
        print()  # Print a newline for readability

# Set the start path to data directory
data_directory = 'data/'  # Adjust this to the path where data resides
print_file_sizes(data_directory)
# Out:
# Directory: data/
#
# Directory: data/pq-linkedin-job-postings
#
# Directory: data/pq-linkedin-job-postings/pq_job_skills
#
# Directory: data/pq-linkedin-job-postings/pq_benefits
#
# Directory: data/pq-linkedin-job-postings/pq_salaries
#
# Directory: data/pq-linkedin-job-postings/pq_skills
#
# Directory: data/pq-linkedin-job-postings/pq_company_industries
#
# Directory: data/pq-linkedin-job-postings/pq_industries
#
# Directory: data/pq-linkedin-job-postings/pq_company_specialities
#
# Directory: data/pq-linkedin-job-postings/pq_companies
#
# Directory: data/pq-linkedin-job-postings/pq_job_postings
#
# Directory: data/pq-linkedin-job-postings/pq_employee
#
# Directory: data/pq-linkedin-job-postings/pq_job_industries
#
# Directory: data/linkedin-job-postings
#     job_postings.csv - 134845243 bytes
#
# Directory: data/linkedin-job-postings/maps
#     skills.csv - 679 bytes
#     industries.csv - 6292 bytes
#
# Directory: data/linkedin-job-postings/company_details
#     employee_counts.csv - 416749 bytes
#     companies.csv - 10953429 bytes
#     company_specialities.csv - 2036857 bytes
#     company_industries.csv - 390677 bytes
#
# Directory: data/linkedin-job-postings/job_details
#     job_industries.csv - 666212 bytes
#     job_skills.csv - 925814 bytes
#     benefits.csv - 840280 bytes
#     salaries.csv - 731493 bytes

# %%
# get the number of records

def print_csv_row_counts(start_path='.'):
    for dirpath, _, filenames in os.walk(start_path):
        for f in filenames:
            if f.endswith('.csv'):
                file_path = os.path.join(dirpath, f)
                try:
                    df = pd.read_csv(file_path)
                    print(f"{file_path}: {len(df.index)} rows")
                except pd.errors.EmptyDataError:
                    print(f"{file_path}: Empty")
                except Exception as e:
                    print(f"{file_path}: Failed to read ({e})")

# Set the start path 
data_directory = 'data/'  
print_csv_row_counts(data_directory)
# Out:
# data/linkedin-job-postings/job_postings.csv: 33246 rows
# data/linkedin-job-postings/maps/skills.csv: 35 rows
# data/linkedin-job-postings/maps/industries.csv: 229 rows
# data/linkedin-job-postings/company_details/employee_counts.csv: 14275 rows
# data/linkedin-job-postings/company_details/companies.csv: 11361 rows
# data/linkedin-job-postings/company_details/company_specialities.csv: 78405 rows
# data/linkedin-job-postings/company_details/company_industries.csv: 12601 rows
# data/linkedin-job-postings/job_details/job_industries.csv: 44091 rows
# data/linkedin-job-postings/job_details/job_skills.csv: 56591 rows
# data/linkedin-job-postings/job_details/benefits.csv: 29325 rows
# data/linkedin-job-postings/job_details/salaries.csv: 13352 rows
